# %%
import pandas as pd
from matplotlib import pyplot as plt

data = r'C:\Users\marek\OneDrive\Pulpit\AiBD\AiBDlab\lab6\Original Data/'

# %%
# oryginalna tabela z danymi

tb_original_ = pd.read_csv(f"{data}14_WIELKOPOLSKIE.csv", sep=',')
print(tb_original_)
# Out:
#      Unnamed: 0  Dni od zakupu       Marka  Wiek kupującego Płeć kupującego  \
# 0             0              3  Electrolux             41.0               M
# 1             1              7  Electrolux             57.0               M
# 2             2              9  Electrolux              NaN               K
# 3             3              8        Beko              NaN               M
# 4             4             10        Beko             35.0               M
# ..          ...            ...         ...              ...             ...
# 529         529              8     Samsung             39.0               M
# 530         530              9  Electrolux             26.0               K
# 531         531              6        Beko             43.0               M
# 532         532              5        Beko              NaN               M
# 533         533              9  Electrolux             57.0               K
#
#      Ocena
# 0      3.0
# 1      3.0
# 2      4.5
# 3      1.5
# 4      2.5
# ..     ...
# 529    1.5
# 530    1.5
# 531    2.5
# 532    2.5
# 533    1.5
#
# [534 rows x 6 columns]

# %%
ocena_marki = tb_original_[['Marka','Ocena', 'Płeć kupującego']]
# ocena_marki_bez_dupli = ocena_marki.drop_duplicates(subset='Marka')
print(ocena_marki)
ocena_marki.to_csv(path_or_buf=f"{data}ocena_marki.csv", sep=";")
# Out:
#           Marka  Ocena Płeć kupującego
# 0    Electrolux    3.0               M
# 1    Electrolux    3.0               M
# 2    Electrolux    4.5               K
# 3          Beko    1.5               M
# 4          Beko    2.5               M
# ..          ...    ...             ...
# 529     Samsung    1.5               M
# 530  Electrolux    1.5               K
# 531        Beko    2.5               M
# 532        Beko    2.5               M
# 533  Electrolux    1.5               K
#
# [534 rows x 3 columns]

# %%
beko = ocena_marki[ocena_marki['Marka']=='Beko']

ocena_kobiety = beko[beko['Płeć kupującego']=='K']
ocena_mezczyz = beko[beko['Płeć kupującego']=='M']
ocena_bd = beko[beko['Płeć kupującego']=='bd.']

x = ['Kobiety', 'Mezczyzni', 'Brak danych']
x_1 = ['Kobiety']
x_2 = ['Mezczyzni']
x_3 = ['Brak danych']

plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
plt.bar(x_3, ocena_bd.mean(), color = 'r')

plt.title("Ocena marki beko ze wzgledu na plec")
plt.ylabel("Srednia ocena")
plt.grid()

print('Srednia ocena kobiet marki Beko:\n',ocena_kobiety.mean())
print('Srednia ocena mezczyz marki Beko:\n',ocena_mezczyz.mean())
print('Brak danych:\n',ocena_bd.mean())

print(ocena_kobiety)
print(ocena_mezczyz)
print(ocena_bd)

ocena_kobiety.to_csv(path_or_buf=f"{data}BEKO_ocena_kobiety.csv", sep=";")
ocena_mezczyz.to_csv(path_or_buf=f"{data}BEKO_ocena_mezczyz.csv", sep=";")
ocena_bd.to_csv(path_or_buf=f"{data}BEKO_ocena_bd.csv", sep=";")
# Out:
# Srednia ocena kobiet marki Beko:
#  Ocena    2.3
# dtype: float64
# Srednia ocena mezczyz marki Beko:
#  Ocena    2.513393
# dtype: float64
# Brak danych:
#  Ocena    3.0
# dtype: float64
#     Marka  Ocena Płeć kupującego
# 61   Beko    2.0               K
# 113  Beko    2.0               K
# 118  Beko    3.0               K
# 137  Beko    1.5               K
# 231  Beko    2.0               K
# 237  Beko    3.5               K
# 325  Beko    3.5               K
# 347  Beko    1.5               K
# 371  Beko    2.5               K
# 395  Beko    1.5               K
#     Marka  Ocena Płeć kupującego
# 3    Beko    1.5               M
# 4    Beko    2.5               M
# 5    Beko    2.0               M
# 13   Beko    3.0               M
# 18   Beko    4.0               M
# ..    ...    ...             ...
# 502  Beko    2.5               M
# 504  Beko    4.0               M
# 520  Beko    2.5               M
# 531  Beko    2.5               M
# 532  Beko    2.5               M
#
# [112 rows x 3 columns]
#     Marka  Ocena Płeć kupującego
# 224  Beko    2.5             bd.
# 246  Beko    3.5             bd.
# 359  Beko    2.5             bd.
# 385  Beko    2.5             bd.
# 498  Beko    4.5             bd.
# 509  Beko    2.0             bd.
# 517  Beko    3.5             bd.
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3761704972.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3761704972.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3761704972.py:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_3, ocena_bd.mean(), color = 'r')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3761704972.py:20: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena kobiet marki Beko:\n',ocena_kobiety.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3761704972.py:21: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena mezczyz marki Beko:\n',ocena_mezczyz.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3761704972.py:22: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Brak danych:\n',ocena_bd.mean())

# %%
# #Sredni wiek
marka = tb_original_[['Marka','Wiek kupującego', 'Płeć kupującego']]
beko_wiek = marka[marka['Marka']=='Beko']
wiek_kobiety = beko_wiek[beko_wiek['Płeć kupującego']=='K']
wiek_mezczyz = beko_wiek[beko_wiek['Płeć kupującego']=='M']
wiek_bd = beko_wiek[beko_wiek['Płeć kupującego']=='bd.']
wiek_kobiety.to_csv(path_or_buf=f"{data}BEKO_wiek_kobiety.csv", sep=";")
wiek_mezczyz.to_csv(path_or_buf=f"{data}BEKO_wiek_mezczy.csv", sep=";")
wiek_bd.to_csv(path_or_buf=f"{data}BEKO_wiek_b.csv", sep=";")

sr_wiek_k = wiek_kobiety.mean()
sr_wiek_m = wiek_mezczyz.mean()
sr_wiek_bd = wiek_bd.mean()
print(sr_wiek_k)
print(sr_wiek_m)
print(sr_wiek_bd)


values = [39.1625, 39.944056, 39.602941]
labels = ['Kobiety', 'Mezczyzni', 'Brak Danych']
plt.pie(values, labels=labels, autopct='%1.3f%%')
plt.title("Procentowy wiek")
plt.show()
# Out:
# Wiek kupującego    38.0
# dtype: float64
# Wiek kupującego    39.558824
# dtype: float64
# Wiek kupującego    46.571429
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3123808212.py:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_k = wiek_kobiety.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3123808212.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_m = wiek_mezczyz.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3123808212.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_bd = wiek_bd.mean()

# %%
tefal = ocena_marki[ocena_marki['Marka']=='Tefal']

ocena_kobiety = tefal[tefal['Płeć kupującego']=='K']
ocena_mezczyz = tefal[tefal['Płeć kupującego']=='M']
ocena_bd = tefal[tefal['Płeć kupującego']=='bd.']

x = ['Kobiety', 'Mezczyzni', 'Brak danych']
x_1 = ['Kobiety']
x_2 = ['Mezczyzni']
x_3 = ['Brak danych']

plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
plt.bar(x_3, ocena_bd.mean(), color = 'r')

plt.title("Ocena marki tefal ze wzgledu na plec")
plt.ylabel("Srednia ocena")
plt.grid()

print('Srednia ocena kobiet marki Tefal:\n',ocena_kobiety.mean())
print('Srednia ocena mezczyz marki Tefal:\n',ocena_mezczyz.mean())
print('Brak danych:\n',ocena_bd.mean())

print(ocena_kobiety)
print(ocena_mezczyz)
print(ocena_bd)

ocena_kobiety.to_csv(path_or_buf=f"{data}Tefal_ocena_kobiety.csv", sep=";")
ocena_mezczyz.to_csv(path_or_buf=f"{data}Tefal_ocena_mezczyz.csv", sep=";")
ocena_bd.to_csv(path_or_buf=f"{data}Tefal_ocena_bd.csv", sep=";")
# Out:
# Srednia ocena kobiet marki Tefal:
#  Ocena    2.5
# dtype: float64
# Srednia ocena mezczyz marki Tefal:
#  Ocena    2.525862
# dtype: float64
# Brak danych:
#  Marka              NaN
# Ocena              NaN
# Płeć kupującego    NaN
# dtype: object
#      Marka  Ocena Płeć kupującego
# 9    Tefal    5.0               K
# 64   Tefal    3.5               K
# 74   Tefal    2.0               K
# 98   Tefal    2.5               K
# 140  Tefal    2.0               K
# 400  Tefal    1.0               K
# 413  Tefal    3.5               K
# 425  Tefal    2.0               K
# 473  Tefal    1.5               K
# 505  Tefal    2.5               K
# 523  Tefal    2.0               K
#      Marka  Ocena Płeć kupującego
# 14   Tefal    3.0               M
# 25   Tefal    3.0               M
# 31   Tefal    2.5               M
# 34   Tefal    2.0               M
# 46   Tefal    1.5               M
# 66   Tefal    4.0               M
# 69   Tefal    1.0               M
# 72   Tefal    3.5               M
# 75   Tefal    2.0               M
# 82   Tefal    2.0               M
# 87   Tefal    1.0               M
# 92   Tefal    0.0               M
# 95   Tefal    2.0               M
# 104  Tefal    3.0               M
# 110  Tefal    1.5               M
# 123  Tefal    1.5               M
# 124  Tefal    4.0               M
# 131  Tefal    1.5               M
# 164  Tefal    2.5               M
# 167  Tefal    5.0               M
# 169  Tefal    3.5               M
# 179  Tefal    1.5               M
# 184  Tefal    5.0               M
# 192  Tefal    3.5               M
# 203  Tefal    1.0               M
# 205  Tefal    1.5               M
# 210  Tefal    3.0               M
# 214  Tefal    1.0               M
# 234  Tefal    1.5               M
# 235  Tefal    1.5               M
# 244  Tefal    0.5               M
# 247  Tefal    3.5               M
# 265  Tefal    3.5               M
# 276  Tefal    4.5               M
# 281  Tefal    1.5               M
# 291  Tefal    1.5               M
# 296  Tefal    1.5               M
# 300  Tefal    1.0               M
# 319  Tefal    3.0               M
# 364  Tefal    2.5               M
# 377  Tefal    4.0               M
# 378  Tefal    4.0               M
# 390  Tefal    1.0               M
# 398  Tefal    3.5               M
# 399  Tefal    3.5               M
# 403  Tefal    5.0               M
# 405  Tefal    2.0               M
# 420  Tefal    1.5               M
# 430  Tefal    3.0               M
# 437  Tefal    1.5               M
# 452  Tefal    4.0               M
# 462  Tefal    3.0               M
# 463  Tefal    1.5               M
# 467  Tefal    4.5               M
# 472  Tefal    2.0               M
# 492  Tefal    5.0               M
# 507  Tefal    3.0               M
# 510  Tefal    2.0               M
# Empty DataFrame
# Columns: [Marka, Ocena, Płeć kupującego]
# Index: []
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/4215382737.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/4215382737.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/4215382737.py:20: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena kobiet marki Tefal:\n',ocena_kobiety.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/4215382737.py:21: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena mezczyz marki Tefal:\n',ocena_mezczyz.mean())

# %%
# #Sredni wiek
marka = tb_original_[['Marka','Wiek kupującego', 'Płeć kupującego']]
tefal_wiek = marka[marka['Marka']=='Tefal']
wiek_kobiety = tefal_wiek[tefal_wiek['Płeć kupującego']=='K']
wiek_mezczyz = tefal_wiek[tefal_wiek['Płeć kupującego']=='M']
wiek_bd = tefal_wiek[tefal_wiek['Płeć kupującego']=='bd.']
wiek_kobiety.to_csv(path_or_buf=f"{data}TEFAL_wiek_kobiety.csv", sep=";")
wiek_mezczyz.to_csv(path_or_buf=f"{data}TEFAL_wiek_mezczy.csv", sep=";")
wiek_bd.to_csv(path_or_buf=f"{data}TEFAL_wiek_b.csv", sep=";")

sr_wiek_k = wiek_kobiety.mean()
sr_wiek_m = wiek_mezczyz.mean()
sr_wiek_bd = wiek_bd.mean()
print(sr_wiek_k)
print(sr_wiek_m)
print(sr_wiek_bd)


values = [39.076923, 40.208333, 45.125]
labels = ['Kobiety', 'Mezczyzni', 'Brak Danych']
plt.pie(values, labels=labels, autopct='%1.3f%%')
plt.title("Procentowy wiek")
plt.show()
# Out:
# Wiek kupującego    37.9
# dtype: float64
# Wiek kupującego    38.612245
# dtype: float64
# Marka              NaN
# Wiek kupującego    NaN
# Płeć kupującego    NaN
# dtype: object
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/4273311610.py:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_k = wiek_kobiety.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/4273311610.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_m = wiek_mezczyz.mean()

# %%
electrolux = ocena_marki[ocena_marki['Marka']=='Electrolux']

ocena_kobiety = electrolux[electrolux['Płeć kupującego']=='K']
ocena_mezczyz = electrolux[electrolux['Płeć kupującego']=='M']
ocena_bd = electrolux[electrolux['Płeć kupującego']=='bd.']

x = ['Kobiety', 'Mezczyzni', 'Brak danych']
x_1 = ['Kobiety']
x_2 = ['Mezczyzni']
x_3 = ['Brak danych']

plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
plt.bar(x_3, ocena_bd.mean(), color = 'r')

plt.title("Ocena marki electrolux ze wzgledu na plec")
plt.ylabel("Srednia ocena")
plt.grid()

print('Srednia ocena kobiet marki Electrolux:\n',ocena_kobiety.mean())
print('Srednia ocena mezczyz marki Electrolux:\n',ocena_mezczyz.mean())
print('Brak danych:\n',ocena_bd.mean())

ocena_kobiety.to_csv(path_or_buf=f"{data}Electrolux_ocena_kobiety.csv", sep=";")
ocena_mezczyz.to_csv(path_or_buf=f"{data}Electrolux_ocena_mezczyz.csv", sep=";")
ocena_bd.to_csv(path_or_buf=f"{data}Electrolux_ocena_bd.csv", sep=";")
# Out:
# Srednia ocena kobiet marki Electrolux:
#  Ocena    2.814286
# dtype: float64
# Srednia ocena mezczyz marki Electrolux:
#  Ocena    2.525568
# dtype: float64
# Brak danych:
#  Ocena    2.375
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2417387595.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2417387595.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2417387595.py:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_3, ocena_bd.mean(), color = 'r')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2417387595.py:20: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena kobiet marki Electrolux:\n',ocena_kobiety.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2417387595.py:21: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena mezczyz marki Electrolux:\n',ocena_mezczyz.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2417387595.py:22: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Brak danych:\n',ocena_bd.mean())

# %%
# #Sredni wiek
marka = tb_original_[['Marka','Wiek kupującego', 'Płeć kupującego']]
Electrolux_wiek = marka[marka['Marka']=='Electrolux']
wiek_kobiety = Electrolux_wiek[Electrolux_wiek['Płeć kupującego']=='K']
wiek_mezczyz = Electrolux_wiek[Electrolux_wiek['Płeć kupującego']=='M']
wiek_bd = Electrolux_wiek[Electrolux_wiek['Płeć kupującego']=='bd.']

wiek_kobiety.to_csv(path_or_buf=f"{data}ELECROLUX_wiek_kobiety.csv", sep=";")
wiek_mezczyz.to_csv(path_or_buf=f"{data}ELECTROLUX_wiek_mezczy.csv", sep=";")
wiek_bd.to_csv(path_or_buf=f"{data}ELECTROLUX_wiek_bd.csv", sep=";")

sr_wiek_k = wiek_kobiety.mean()
sr_wiek_m = wiek_mezczyz.mean()
sr_wiek_bd = wiek_bd.mean()
print(sr_wiek_k)
print(sr_wiek_m)
print(sr_wiek_bd)


values = [40.625, 41.76, 38.333333]
labels = ['Kobiety', 'Mezczyzni', 'Brak Danych']
plt.pie(values, labels=labels, autopct='%1.3f%%')
plt.title("Procentowy wiek")
plt.show()
# Out:
# Wiek kupującego    38.8125
# dtype: float64
# Wiek kupującego    39.310127
# dtype: float64
# Wiek kupującego    38.0
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2322338127.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_k = wiek_kobiety.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2322338127.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_m = wiek_mezczyz.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/2322338127.py:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_bd = wiek_bd.mean()

# %% [markdown]
# ***Samsung***

# %%
samsung = ocena_marki[ocena_marki['Marka']=='Samsung']

ocena_kobiety = samsung[samsung['Płeć kupującego']=='K']
ocena_mezczyz = samsung[samsung['Płeć kupującego']=='M']
ocena_bd = samsung[samsung['Płeć kupującego']=='bd.']

x = ['Kobiety', 'Mezczyzni', 'Brak danych']
x_1 = ['Kobiety']
x_2 = ['Mezczyzni']
x_3 = ['Brak danych']

plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
plt.bar(x_3, ocena_bd.mean(), color = 'r')

plt.title("Ocena marki samsung ze wzgledu na plec")
plt.ylabel("Srednia ocena")
plt.grid()

print('Srednia ocena kobiet marki Samsung:\n',ocena_kobiety.mean())
print('Srednia ocena mezczyz marki Samsung:\n',ocena_mezczyz.mean())
print('Brak danych:\n',ocena_bd.mean())

ocena_kobiety.to_csv(path_or_buf=f"{data}Samsung_ocena_kobiety.csv", sep=";")
ocena_mezczyz.to_csv(path_or_buf=f"{data}Samsung_ocena_mezczyz.csv", sep=";")
ocena_bd.to_csv(path_or_buf=f"{data}Samsung_ocena_bd.csv", sep=";")
# Out:
# Srednia ocena kobiet marki Samsung:
#  Ocena    2.875
# dtype: float64
# Srednia ocena mezczyz marki Samsung:
#  Ocena    2.066667
# dtype: float64
# Brak danych:
#  Ocena    1.75
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3677398080.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3677398080.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3677398080.py:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_3, ocena_bd.mean(), color = 'r')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3677398080.py:20: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena kobiet marki Samsung:\n',ocena_kobiety.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3677398080.py:21: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena mezczyz marki Samsung:\n',ocena_mezczyz.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/3677398080.py:22: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Brak danych:\n',ocena_bd.mean())

# %%
marka = tb_original_[['Marka','Wiek kupującego', 'Płeć kupującego']]
Samsung_wiek = marka[marka['Marka']=='Samsung']
wiek_kobiety = Samsung_wiek[Samsung_wiek['Płeć kupującego']=='K']
wiek_mezczyz = Samsung_wiek[Samsung_wiek['Płeć kupującego']=='M']
wiek_bd = Samsung_wiek[Samsung_wiek['Płeć kupującego']=='bd.']

wiek_kobiety.to_csv(path_or_buf=f"{data}SAMSUNG_wiek_kobiety.csv", sep=";")
wiek_mezczyz.to_csv(path_or_buf=f"{data}SAMSUNG_wiek_mezczy.csv", sep=";")
wiek_bd.to_csv(path_or_buf=f"{data}SAMSUNG_wiek_bd.csv", sep=";")

sr_wiek_k = wiek_kobiety.mean()
sr_wiek_m = wiek_mezczyz.mean()
sr_wiek_bd = wiek_bd.mean()
print(sr_wiek_k)
print(sr_wiek_m)
print(sr_wiek_bd)


values = [34.25, 42.857143, 35.0]
labels = ['Kobiety', 'Mezczyzni', 'Brak Danych']
plt.pie(values, labels=labels, autopct='%1.3f%%')
plt.title("Procentowy wiek")
plt.show()
# Out:
# Wiek kupującego    39.75
# dtype: float64
# Wiek kupującego    43.296296
# dtype: float64
# Wiek kupującego    38.0
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1616448923.py:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_k = wiek_kobiety.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1616448923.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_m = wiek_mezczyz.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1616448923.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_bd = wiek_bd.mean()

# %% [markdown]
# ***DYSON***

# %%
dyson = ocena_marki[ocena_marki['Marka']=='Dyson']

ocena_kobiety = dyson[dyson['Płeć kupującego']=='K']
ocena_mezczyz = dyson[dyson['Płeć kupującego']=='M']
ocena_bd = dyson[dyson['Płeć kupującego']=='bd.']

x = ['Kobiety', 'Mezczyzni', 'Brak danych']
x_1 = ['Kobiety']
x_2 = ['Mezczyzni']
x_3 = ['Brak danych']

plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
plt.bar(x_3, ocena_bd.mean(), color = 'r')

plt.title("Ocena marki Dyson ze wzgledu na plec")
plt.ylabel("Srednia ocena")
plt.grid()

print('Srednia ocena kobiet marki Dyson:\n',ocena_kobiety.mean())
print('Srednia ocena mezczyz marki Dyson:\n',ocena_mezczyz.mean())
print('Brak danych:\n',ocena_bd.mean())

ocena_kobiety.to_csv(path_or_buf=f"{data}Dyson_ocena_kobiety.csv", sep=";")
ocena_mezczyz.to_csv(path_or_buf=f"{data}Dyson_ocena_mezczyz.csv", sep=";")
ocena_bd.to_csv(path_or_buf=f"{data}Dyson_ocena_bd.csv", sep=";")
# Out:
# Srednia ocena kobiet marki Dyson:
#  Ocena    2.444444
# dtype: float64
# Srednia ocena mezczyz marki Dyson:
#  Ocena    2.310811
# dtype: float64
# Brak danych:
#  Ocena    2.75
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1555770288.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_1, ocena_kobiety.mean(), color = 'm')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1555770288.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_2, ocena_mezczyz.mean(), color = 'b')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1555770288.py:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.bar(x_3, ocena_bd.mean(), color = 'r')
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1555770288.py:20: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena kobiet marki Dyson:\n',ocena_kobiety.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1555770288.py:21: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Srednia ocena mezczyz marki Dyson:\n',ocena_mezczyz.mean())
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1555770288.py:22: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Brak danych:\n',ocena_bd.mean())

# %%
marka = tb_original_[['Marka','Wiek kupującego', 'Płeć kupującego']]
Dyson_wiek = marka[marka['Marka']=='Dyson']
wiek_kobiety = Dyson_wiek[Dyson_wiek['Płeć kupującego']=='K']
wiek_mezczyz = Dyson_wiek[Dyson_wiek['Płeć kupującego']=='M']
wiek_bd = Dyson_wiek[Dyson_wiek['Płeć kupującego']=='bd.']

wiek_kobiety.to_csv(path_or_buf=f"{data}DYSON_wiek_kobiety.csv", sep=";")
wiek_mezczyz.to_csv(path_or_buf=f"{data}DYSON_wiek_mezczy.csv", sep=";")
wiek_bd.to_csv(path_or_buf=f"{data}DYSON_wiek_bd.csv", sep=";")

sr_wiek_k = wiek_kobiety.mean()
sr_wiek_m = wiek_mezczyz.mean()
sr_wiek_bd = wiek_bd.mean()
print(sr_wiek_k)
print(sr_wiek_m)
print(sr_wiek_bd)


values = [44.1,42.769231, 48.6]
labels = ['Kobiety', 'Mezczyzni', 'Brak Danych']
plt.pie(values, labels=labels, autopct='%1.3f%%')
plt.title("Procentowy wiek")
plt.show()
# Out:
# Wiek kupującego    39.444444
# dtype: float64
# Wiek kupującego    42.716667
# dtype: float64
# Wiek kupującego    42.0
# dtype: float64
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1190337009.py:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_k = wiek_kobiety.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1190337009.py:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_m = wiek_mezczyz.mean()
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_19752/1190337009.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sr_wiek_bd = wiek_bd.mean()

# %%
# sr_ocena = ocena_marki.mean(axis='Marka')

plec = ocena_marki['Płeć kupującego'].value_counts(ascending=True)
plt.plot(plec)
print('Liczba klientow ze wzgledu na plec\n', plec)
plt.title("Liczba klientow ze wzgledu na plec")
plt.ylabel("Ilosc ludzi")
plt.grid()
# Out:
# Liczba klientow ze wzgledu na plec
#  bd.     15
# K       69
# M      450
# Name: Płeć kupującego, dtype: int64
